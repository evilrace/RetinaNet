# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import data_preprocess
img = tf.io.read_file(r"F:\dataset\kitti\data_object_image_2\training\image_2\000000.png")
img = tf.image.decode_image(img)

fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].imshow(img)
plt.axis('off')
img, size, _ = data_preprocess.resize_and_pad_image(img)
img = tf.cast(img, tf.int32)
ax[1].imshow(img)
plt.show()
